# %%
import duckdb
import gspread
import pandas as pd
# import numpy as np
from google.oauth2.service_account import Credentials

SCOPES = [
    # 'https://www.googleapis.com/auth/bigquery',
    'https://www.googleapis.com/auth/drive',
    'https://www.googleapis.com/auth/spreadsheets'
    # ,'https://www.googleapis.com/auth/devstorage.full_control'
]

credentials = Credentials.from_service_account_file(r'.secrets\ads-txt-validator-BQ.json', scopes=SCOPES)

# %%
sheet_client:gspread.Client = gspread.Client(auth=credentials)

def adhoc_gsheet_pull(worksheet_name:str):

        google_sheet_id = '1DLevo_k0LTfIHH7wL9n08NfYnpq_CbSF5RLNIMaIJU8'
        # worksheet_name = 'main_file'

        spreadsheet = sheet_client.open_by_key(google_sheet_id)

        worksheet = spreadsheet.worksheet(worksheet_name)

        list_of_dicts = worksheet.get_all_records()

        df = pd.DataFrame(list_of_dicts)

        try:
            if "ORG_ID" in df.columns:
                df = df.astype({"ORG_ID":"int64"}).astype({"ORG_ID":"string"})
        except Exception as e:
            print(f"{e=}")

        # print(df.dtypes)

        return df

main_file_df = adhoc_gsheet_pull(worksheet_name = 'main_file')
expected_ads_txt_df = adhoc_gsheet_pull(worksheet_name = 'ads_txt_lines')
# main_file_df

# %%
len(main_file_df) * len(expected_ads_txt_df)
# Out:
# 1656

# %%
raw_tbl = duckdb.read_parquet(r'data_output\2025-04-15\ads_txt_success_2025-04-15-13-49-58.parquet')
err_tbl = duckdb.read_parquet(r'data_output\2025-04-15\ads_txt_failure_2025-04-15-13-49-58.parquet')

# %%
output_tbl = duckdb.sql(
    """
CREATE OR REPLACE MACRO SAFE_OFFSET(arr, idx) AS (
    CASE
        WHEN idx > 0 AND idx <= array_length(arr) THEN arr[idx]
        ELSE NULL
    END
);
WITH main_client_tbl AS (
  SELECT 
  Publisher AS publisher
  , ORG_ID AS org_id
  , CASE WHEN Inventory_Type = 'App - (app-ads.txt)' THEN 'app-ads.txt'
         WHEN Inventory_Type = 'Web - (ads.txt)' THEN 'ads.txt'
         ELSE Inventory_Type END AS inventory_type
  , Relationship_Type AS relationship_type
  , Account_Manager as account_manager_name
  , Account_Manager_Email as account_manager_email
  , Domain AS domain
  , Ad_Request AS ad_request
  , Revenue AS revenue
  FROM main_file_df
  WHERE 
  domain IS NOT NULL
  AND inventory_type IS NOT NULL
  AND org_id IS NOT NULL
  AND relationship_type IS NOT NULL
),

required_domains AS (
  SELECT DISTINCT domain, inventory_type, CONCAT(domain,'--',inventory_type) AS relevent_domains_key FROM main_client_tbl
),

required_bronze_data AS (
  SELECT LOWER(REGEXP_REPLACE(REPLACE(ads_txt_line, ' ', ''), '#.*','')) AS ads_txt_lines
  , domain
  , inventory_type
  , ads_txt_url AS ads_txt_url
  FROM raw_tbl
  WHERE 
  CONCAT(domain,'--',inventory_type) IN (SELECT DISTINCT relevent_domains_key from required_domains) 
  AND ads_txt_line is not null and  not starts_with(ads_txt_line, '#')
),

duplicated_rows_bronze_data AS (
  SELECT 
  ads_txt_lines
  , domain
  , inventory_type
  , ads_txt_url
  -- , execution_date 
  ,trim(SAFE_OFFSET(split(ads_txt_lines, ','),1))  as ssp_domain
  ,trim(SAFE_OFFSET(split(ads_txt_lines, ','),2))  as pub_id
  ,trim(SAFE_OFFSET(split(ads_txt_lines, ','),3))  as relationship_type
  ,trim(SAFE_OFFSET(split(ads_txt_lines, ','),4))  as ssp_id
  ,ROW_NUMBER() OVER (
      PARTITION BY 
        domain, 
        inventory_type, 
        ads_txt_url, 
        -- execution_date, 
        TRIM(SAFE_OFFSET(SPLIT(ads_txt_lines, ','),1)),  -- ssp_domain
        TRIM(SAFE_OFFSET(SPLIT(ads_txt_lines, ','),2)),  -- pub_id
        TRIM(SAFE_OFFSET(SPLIT(ads_txt_lines, ','),3))   -- relationship_type
      -- ORDER BY execution_date DESC  -- Keeping the latest record
    ) AS row_num
  FROM required_bronze_data
), 

cleaned_bronze_data AS (
  SELECT * FROM duplicated_rows_bronze_data WHERE row_num = 1
),

web_ads_txt_lines AS (
  SELECT LOWER(REGEXP_REPLACE(REPLACE(ads_txt_line, ' ', ''), '#.*','')) AS ads_txt_lines
  FROM expected_ads_txt_df
),

web_pubs AS (
  SELECT * FROM main_client_tbl WHERE inventory_type = 'app-ads.txt'
),

combined_ads_txt_lines_checking AS (
  SELECT publisher
  , org_id
  , inventory_type
  , relationship_type
  , account_manager_name
  , account_manager_email
  , domain
  , ad_request
  , revenue
  , REPLACE(ads_txt_lines, '[org_id],[relation_type]', LOWER(CONCAT(org_id,',',relationship_type))) AS ads_txt_lines
  FROM web_pubs CROSS JOIN web_ads_txt_lines 
),

cleaned_pubs_data AS (
  SELECT publisher
  , org_id
  , inventory_type
  , relationship_type AS relationship_type_given
  , account_manager_name
  , account_manager_email
  , domain
  , ad_request
  , revenue
  , ads_txt_lines 
  ,trim(SAFE_OFFSET(split(ads_txt_lines, ','),1))  as ssp_domain
  ,trim(SAFE_OFFSET(split(ads_txt_lines, ','),2))  as pub_id
  ,trim(SAFE_OFFSET(split(ads_txt_lines, ','),3))  as relationship_type
  ,trim(SAFE_OFFSET(split(ads_txt_lines, ','),4))  as ssp_id
FROM combined_ads_txt_lines_checking),

error_tbl AS (SELECT
    domain,
    inventory_type,
    repr_error_msg,
    response_code
FROM (
    SELECT
        domain,
        inventory_type,
        repr_error_msg,
        response_code,
        ROW_NUMBER() OVER (
            PARTITION BY domain, inventory_type
            ORDER BY repr_error_msg
        ) AS rn
    FROM err_tbl
)
WHERE rn = 1
)



SELECT 
pubs_data.publisher
,pubs_data.org_id
,pubs_data.inventory_type
,pubs_data.relationship_type_given
,pubs_data.account_manager_name
,pubs_data.account_manager_email
,pubs_data.domain
,pubs_data.ad_request
,pubs_data.revenue
,pubs_data.ads_txt_lines
,pubs_data.ssp_domain
,pubs_data.pub_id
,pubs_data.relationship_type
,pubs_data.ssp_id
,scraped.ads_txt_lines AS ads_txt_lines_scraped
,scraped.domain AS domain_scraped
,scraped.inventory_type AS inventory_type_scraped
,scraped.ads_txt_url AS ads_txt_url_scraped
,scraped.ssp_domain AS ssp_domain_scraped
,scraped.pub_id AS pub_id_scraped
,scraped.relationship_type AS relationship_type_scraped
,scraped.ssp_id AS ssp_id_scraped
,CASE WHEN scraped.ads_txt_lines IS NULL THEN 'missing' ELSE 'present' END AS ads_txt_status
,CASE WHEN error_tbl.repr_error_msg IS NOT NULL THEN 'failure' WHEN scraped.ads_txt_lines IS NULL THEN 'missing' ELSE 'present' END AS ads_txt_status_v2
,error_tbl.repr_error_msg
,error_tbl.response_code
FROM cleaned_pubs_data AS pubs_data LEFT JOIN cleaned_bronze_data AS scraped
ON pubs_data.pub_id = scraped.pub_id
AND pubs_data.inventory_type = scraped.inventory_type
AND pubs_data.domain = scraped.domain
AND pubs_data.ssp_domain = scraped.ssp_domain

LEFT JOIN error_tbl AS error_tbl
ON pubs_data.inventory_type = error_tbl.inventory_type
AND pubs_data.domain = error_tbl.domain

    """
)

# %%
output_tbl.show()
# Out:
# ┌──────────────────────────┬─────────┬────────────────┬─────────────────────────┬─────────────────────────┬─────────────────────────┬──────────────────────────┬────────────┬─────────┬─────────────────────────────────────────────────────┬────────────────────┬──────────────────────────┬───────────────────┬──────────────────┬────────────────────────────────────────────────────┬───────────────────────┬────────────────────────┬───────────────────────────────────────────┬────────────────────┬────────────────┬───────────────────────────┬──────────────────┬────────────────┬───────────────────┬────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬───────────────┐
# │        publisher         │ org_id  │ inventory_type │ relationship_type_given │  account_manager_name   │  account_manager_email  │          domain          │ ad_request │ revenue │                    ads_txt_lines                    │     ssp_domain     │          pub_id          │ relationship_type │      ssp_id      │               ads_txt_lines_scraped                │    domain_scraped     │ inventory_type_scraped │            ads_txt_url_scraped            │ ssp_domain_scraped │ pub_id_scraped │ relationship_type_scraped │  ssp_id_scraped  │ ads_txt_status │ ads_txt_status_v2 │                                                           repr_error_msg                                                           │ response_code │
# │         varchar          │ varchar │    varchar     │         varchar         │         varchar         │         varchar         │         varchar          │   int64    │  int64  │                       varchar                       │      varchar       │         varchar          │      varchar      │     varchar      │                      varchar                       │        varchar        │        varchar         │                  varchar                  │      varchar       │    varchar     │          varchar          │     varchar      │    varchar     │      varchar      │                                                              varchar                                                               │    varchar    │
# ├──────────────────────────┼─────────┼────────────────┼─────────────────────────┼─────────────────────────┼─────────────────────────┼──────────────────────────┼────────────┼─────────┼─────────────────────────────────────────────────────┼────────────────────┼──────────────────────────┼───────────────────┼──────────────────┼────────────────────────────────────────────────────┼───────────────────────┼────────────────────────┼───────────────────────────────────────────┼────────────────────┼────────────────┼───────────────────────────┼──────────────────┼────────────────┼───────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────┤
# │ basketballnetwork.net    │ 17      │ ads.txt        │ DIRECT                  │ publishers@test_ssp.com │ publishers@test_ssp.com │ basketballnetwork.net    │       1000 │      10 │ appnexus.com,9538,reseller,f5ab79cb980f11d1         │ appnexus.com       │ 9538                     │ reseller          │ f5ab79cb980f11d1 │ appnexus.com,9538,reseller,f5ab79cb980f11d1        │ basketballnetwork.net │ ads.txt                │ https://www.basketballnetwork.net/ads.txt │ appnexus.com       │ 9538           │ reseller                  │ f5ab79cb980f11d1 │ present        │ present           │ NULL                                                                                                                               │ NULL          │
# │ jpost.com                │ 15      │ ads.txt        │ DIRECT                  │ publishers@test_ssp.com │ publishers@test_ssp.com │ jpost.com                │       1000 │      10 │ appnexus.com,9538,reseller,f5ab79cb980f11d1         │ appnexus.com       │ 9538                     │ reseller          │ f5ab79cb980f11d1 │ appnexus.com,9538,reseller,f5ab79cb980f11d1        │ jpost.com             │ ads.txt                │ https://www.jpost.com/ads.txt             │ appnexus.com       │ 9538           │ reseller                  │ f5ab79cb980f11d1 │ present        │ present           │ NULL                                                                                                                               │ NULL          │
# │ justjared.com            │ 192     │ ads.txt        │ DIRECT                  │ publishers@test_ssp.com │ publishers@test_ssp.com │ justjared.com            │       1000 │      10 │ appnexus.com,9538,reseller,f5ab79cb980f11d1         │ appnexus.com       │ 9538                     │ reseller          │ f5ab79cb980f11d1 │ appnexus.com,9538,reseller,f5ab79cb980f11d1        │ justjared.com         │ ads.txt                │ https://www.justjared.com/ads.txt         │ appnexus.com       │ 9538           │ reseller                  │ f5ab79cb980f11d1 │ present        │ present           │ NULL                                                                                                                               │ NULL          │
# │ realcleardefense.com     │ 172     │ ads.txt        │ DIRECT                  │ publishers@test_ssp.com │ publishers@test_ssp.com │ realcleardefense.com     │       1000 │      10 │ rubiconproject.com,24434,reseller,0bfd66d529a55807  │ rubiconproject.com │ 24434                    │ reseller          │ 0bfd66d529a55807 │ rubiconproject.com,24434,reseller,0bfd66d529a55807 │ realcleardefense.com  │ ads.txt                │ https://www.realcleardefense.com/ads.txt  │ rubiconproject.com │ 24434          │ reseller                  │ 0bfd66d529a55807 │ present        │ present           │ NULL                                                                                                                               │ NULL          │
# │ soaphub.com              │ 20      │ ads.txt        │ DIRECT                  │ publishers@test_ssp.com │ publishers@test_ssp.com │ soaphub.com              │       1000 │      10 │ appnexus.com,9538,reseller,f5ab79cb980f11d1         │ appnexus.com       │ 9538                     │ reseller          │ f5ab79cb980f11d1 │ appnexus.com,9538,direct                           │ soaphub.com           │ ads.txt                │ https://www.soaphub.com/ads.txt           │ appnexus.com       │ 9538           │ direct                    │ NULL             │ present        │ present           │ NULL                                                                                                                               │ NULL          │
# │ usnews.com               │ 187     │ ads.txt        │ DIRECT                  │ publishers@test_ssp.com │ publishers@test_ssp.com │ usnews.com               │       1000 │      10 │ rubiconproject.com,24434,reseller,0bfd66d529a55807  │ rubiconproject.com │ 24434                    │ reseller          │ 0bfd66d529a55807 │ rubiconproject.com,24434,reseller,0bfd66d529a55807 │ usnews.com            │ ads.txt                │ https://www.usnews.com/ads.txt            │ rubiconproject.com │ 24434          │ reseller                  │ 0bfd66d529a55807 │ present        │ present           │ NULL                                                                                                                               │ NULL          │
# │ wsoctv.com               │ 197     │ ads.txt        │ DIRECT                  │ publishers@test_ssp.com │ publishers@test_ssp.com │ wsoctv.com               │       1000 │      10 │ lijit.com,253233,reseller,fafdf38b16bf6b2b          │ lijit.com          │ 253233                   │ reseller          │ fafdf38b16bf6b2b │ lijit.com,253233,reseller,fafdf38b16bf6b2b         │ wsoctv.com            │ ads.txt                │ https://www.wsoctv.com/ads.txt            │ lijit.com          │ 253233         │ reseller                  │ fafdf38b16bf6b2b │ present        │ present           │ NULL                                                                                                                               │ NULL          │
# │ athlonsports.com         │ 2       │ ads.txt        │ DIRECT                  │ publishers@test_ssp.com │ publishers@test_ssp.com │ athlonsports.com         │       1000 │      10 │ rubiconproject.com,24434,reseller,0bfd66d529a55807  │ rubiconproject.com │ 24434                    │ reseller          │ 0bfd66d529a55807 │ rubiconproject.com,24434,reseller,0bfd66d529a55807 │ athlonsports.com      │ ads.txt                │ https://www.athlonsports.com/ads.txt      │ rubiconproject.com │ 24434          │ reseller                  │ 0bfd66d529a55807 │ present        │ present           │ NULL                                                                                                                               │ NULL          │
# │ basketballnetwork.net    │ 17      │ ads.txt        │ DIRECT                  │ publishers@test_ssp.com │ publishers@test_ssp.com │ basketballnetwork.net    │       1000 │      10 │ lijit.com,253233,reseller,fafdf38b16bf6b2b          │ lijit.com          │ 253233                   │ reseller          │ fafdf38b16bf6b2b │ lijit.com,253233,reseller,fafdf38b16bf6b2b         │ basketballnetwork.net │ ads.txt                │ https://www.basketballnetwork.net/ads.txt │ lijit.com          │ 253233         │ reseller                  │ fafdf38b16bf6b2b │ present        │ present           │ NULL                                                                                                                               │ NULL          │
# │ boston25news.com         │ 145     │ ads.txt        │ DIRECT                  │ publishers@test_ssp.com │ publishers@test_ssp.com │ boston25news.com         │       1000 │      10 │ rubiconproject.com,24434,reseller,0bfd66d529a55807  │ rubiconproject.com │ 24434                    │ reseller          │ 0bfd66d529a55807 │ rubiconproject.com,24434,reseller,0bfd66d529a55807 │ boston25news.com      │ ads.txt                │ https://www.boston25news.com/ads.txt      │ rubiconproject.com │ 24434          │ reseller                  │ 0bfd66d529a55807 │ present        │ present           │ NULL                                                                                                                               │ NULL          │
# │     ·                    │  ·      │    ·           │   ·                     │            ·            │            ·            │     ·                    │         ·  │       · │                        ·                            │       ·            │   ·                      │    ·              │  ·               │  ·                                                 │  ·                    │  ·                     │  ·                                        │  ·                 │  ·             │  ·                        │  ·               │    ·           │    ·              │  ·                                                                                                                                 │ ·             │
# │     ·                    │  ·      │    ·           │   ·                     │            ·            │            ·            │     ·                    │         ·  │       · │                        ·                            │       ·            │   ·                      │    ·              │  ·               │  ·                                                 │  ·                    │  ·                     │  ·                                        │  ·                 │  ·             │  ·                        │  ·               │    ·           │    ·              │  ·                                                                                                                                 │ ·             │
# │     ·                    │  ·      │    ·           │   ·                     │            ·            │            ·            │     ·                    │         ·  │       · │                        ·                            │       ·            │   ·                      │    ·              │  ·               │  ·                                                 │  ·                    │  ·                     │  ·                                        │  ·                 │  ·             │  ·                        │  ·               │    ·           │    ·              │  ·                                                                                                                                 │ ·             │
# │ goal.comes               │ 198     │ ads.txt        │ DIRECT                  │ publishers@test_ssp.com │ publishers@test_ssp.com │ goal.comes               │       1000 │      10 │ risecodes.com,67a38418e115360001678324,reseller     │ risecodes.com      │ 67a38418e115360001678324 │ reseller          │ NULL             │ NULL                                               │ NULL                  │ NULL                   │ NULL                                      │ NULL               │ NULL           │ NULL                      │ NULL             │ missing        │ failure           │ <twisted.python.failure.Failure twisted.internet.error.DNSLookupError: DNS lookup failed: no results for hostname lookup: comes..> │ NA            │
# │ dknetwork.draftkings.com │ 142     │ ads.txt        │ DIRECT                  │ publishers@test_ssp.com │ publishers@test_ssp.com │ dknetwork.draftkings.com │       1000 │      10 │ sharethrough.com,z7d3ygnp,reseller,d53b998a7bd4ecd2 │ sharethrough.com   │ z7d3ygnp                 │ reseller          │ d53b998a7bd4ecd2 │ NULL                                               │ NULL                  │ NULL                   │ NULL                                      │ NULL               │ NULL           │ NULL                      │ NULL             │ missing        │ failure           │ <twisted.python.failure.Failure scrapy.spidermiddlewares.httperror.HttpError: Ignoring non-200 response>                           │ 403           │
# │ goal.comit               │ 161     │ ads.txt        │ DIRECT                  │ publishers@test_ssp.com │ publishers@test_ssp.com │ goal.comit               │       1000 │      10 │ appnexus.com,9538,reseller,f5ab79cb980f11d1         │ appnexus.com       │ 9538                     │ reseller          │ f5ab79cb980f11d1 │ NULL                                               │ NULL                  │ NULL                   │ NULL                                      │ NULL               │ NULL           │ NULL                      │ NULL             │ missing        │ failure           │ <twisted.python.failure.Failure twisted.internet.error.DNSLookupError: DNS lookup failed: no results for hostname lookup: comit..> │ NA            │
# │ waaytv.com               │ 162     │ ads.txt        │ DIRECT                  │ publishers@test_ssp.com │ publishers@test_ssp.com │ waaytv.com               │       1000 │      10 │ rubiconproject.com,24434,reseller,0bfd66d529a55807  │ rubiconproject.com │ 24434                    │ reseller          │ 0bfd66d529a55807 │ NULL                                               │ NULL                  │ NULL                   │ NULL                                      │ NULL               │ NULL           │ NULL                      │ NULL             │ missing        │ failure           │ ads_txt_page_not_found                                                                                                             │ 200           │
# │ goal.comes               │ 198     │ ads.txt        │ DIRECT                  │ publishers@test_ssp.com │ publishers@test_ssp.com │ goal.comes               │       1000 │      10 │ media.net,8cuv34pj4,reseller                        │ media.net          │ 8cuv34pj4                │ reseller          │ NULL             │ NULL                                               │ NULL                  │ NULL                   │ NULL                                      │ NULL               │ NULL           │ NULL                      │ NULL             │ missing        │ failure           │ <twisted.python.failure.Failure twisted.internet.error.DNSLookupError: DNS lookup failed: no results for hostname lookup: comes..> │ NA            │
# │ wgxa.tv.com              │ 185     │ ads.txt        │ DIRECT                  │ publishers@test_ssp.com │ publishers@test_ssp.com │ wgxa.tv.com              │       1000 │      10 │ lijit.com,253233,reseller,fafdf38b16bf6b2b          │ lijit.com          │ 253233                   │ reseller          │ fafdf38b16bf6b2b │ NULL                                               │ NULL                  │ NULL                   │ NULL                                      │ NULL               │ NULL           │ NULL                      │ NULL             │ missing        │ failure           │ <twisted.python.failure.Failure twisted.internet.error.DNSLookupError: DNS lookup failed: no results for hostname lookup: tv.com.> │ NA            │
# │ goal.comes               │ 198     │ ads.txt        │ DIRECT                  │ publishers@test_ssp.com │ publishers@test_ssp.com │ goal.comes               │       1000 │      10 │ lijit.com,253233,reseller,fafdf38b16bf6b2b          │ lijit.com          │ 253233                   │ reseller          │ fafdf38b16bf6b2b │ NULL                                               │ NULL                  │ NULL                   │ NULL                                      │ NULL               │ NULL           │ NULL                      │ NULL             │ missing        │ failure           │ <twisted.python.failure.Failure twisted.internet.error.DNSLookupError: DNS lookup failed: no results for hostname lookup: comes..> │ NA            │
# │ wgxa.tv.com              │ 185     │ ads.txt        │ DIRECT                  │ publishers@test_ssp.com │ publishers@test_ssp.com │ wgxa.tv.com              │       1000 │      10 │ sharethrough.com,z7d3ygnp,reseller,d53b998a7bd4ecd2 │ sharethrough.com   │ z7d3ygnp                 │ reseller          │ d53b998a7bd4ecd2 │ NULL                                               │ NULL                  │ NULL                   │ NULL                                      │ NULL               │ NULL           │ NULL                      │ NULL             │ missing        │ failure           │ <twisted.python.failure.Failure twisted.internet.error.DNSLookupError: DNS lookup failed: no results for hostname lookup: tv.com.> │ NA            │
# │ post-gazette.com         │ 68      │ ads.txt        │ DIRECT                  │ publishers@test_ssp.com │ publishers@test_ssp.com │ post-gazette.com         │       1000 │      10 │ pubmatic.com,159302,reseller,5d62403b186f2ace       │ pubmatic.com       │ 159302                   │ reseller          │ 5d62403b186f2ace │ NULL                                               │ NULL                  │ NULL                   │ NULL                                      │ NULL               │ NULL           │ NULL                      │ NULL             │ missing        │ failure           │ <twisted.python.failure.Failure twisted.internet.error.TimeoutError: User timeout caused connection failure.>                      │ NA            │
# │ waaytv.com               │ 162     │ ads.txt        │ DIRECT                  │ publishers@test_ssp.com │ publishers@test_ssp.com │ waaytv.com               │       1000 │      10 │ pubmatic.com,159302,reseller,5d62403b186f2ace       │ pubmatic.com       │ 159302                   │ reseller          │ 5d62403b186f2ace │ NULL                                               │ NULL                  │ NULL                   │ NULL                                      │ NULL               │ NULL           │ NULL                      │ NULL             │ missing        │ failure           │ ads_txt_page_not_found                                                                                                             │ 200           │
# ├──────────────────────────┴─────────┴────────────────┴─────────────────────────┴─────────────────────────┴─────────────────────────┴──────────────────────────┴────────────┴─────────┴─────────────────────────────────────────────────────┴────────────────────┴──────────────────────────┴───────────────────┴──────────────────┴────────────────────────────────────────────────────┴───────────────────────┴────────────────────────┴───────────────────────────────────────────┴────────────────────┴────────────────┴───────────────────────────┴──────────────────┴────────────────┴───────────────────┴────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴───────────────┤
# │ 1660 rows (20 shown)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   26 columns │
# └───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
output_tbl.to_csv("beeswax.csv",overwrite=True, header=True)
